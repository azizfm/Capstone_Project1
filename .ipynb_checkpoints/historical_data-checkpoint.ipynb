# %%
import pandas as pd

# %%
# Captures product data from excel historical data file
product_data = pd.read_csv('C:\\Users\\azizs\\TEKsystems\\Capstone_Project1\\csv_raw_data\\capstone1_Product_data.csv')

# %%
# Captures Sales Team Data from historical Excel file
Sales_Team_data = pd.read_csv('C:\\Users\\azizs\\TEKsystems\\Capstone_Project1\\csv_raw_data\\capstone1_Sales_Team_Data.csv')

# %%
# Captures 'Sunday data' from historical Excel file
sunday_data = pd.read_csv('C:\\Users\\azizs\\TEKsystems\\Capstone_Project1\\csv_raw_data\\capstone1_Sunday_data.csv')

# %%
# Captures '52 wk data from historical Excel file
wk52_data = pd.read_csv('C:\\Users\\azizs\\TEKsystems\\Capstone_Project1\\csv_raw_data\\capstone1_52_wks_data.csv')

# %%
# Joins two table together from historical Excel Data file
pd.concat([Sales_Team_data,emp_data], axis=1)
# Out:
#       Sales Team Lead PayGrade Region   EmpID IsFound  Index ITEM_CODE  \
# 0         Evans, Gina      C12     NW  EMP244    True      1  PROD_001
# 1       Lawson, Harry      C11     NW  EMP256    True      2  PROD_001
# 2      Bachmann, Jane      C13     NW  EMP234    True      3  PROD_002
# 3    Clement, Beverly      C14     SW  EMP267    True      4  PROD_002
# 4        Allen, Maude      C12     SW  EMP290    True      5  PROD_003
# ..                ...      ...    ...     ...     ...    ...       ...
# 155               NaN      NaN    NaN     NaN     NaN    156   ESP_008
# 156               NaN      NaN    NaN     NaN     NaN    157   ESP_008
# 157               NaN      NaN    NaN     NaN     NaN    158   ESP_008
# 158               NaN      NaN    NaN     NaN     NaN    159   ESP_008
# 159               NaN      NaN    NaN     NaN     NaN    160   ESP_008
#
#      EMP_ID  Year  W0  ...  W42  W43  W44  W45  W46  W47  W48  W49  W50  W51
# ...

# %%
Sales_Team_data.info()    #  Gives the data types for each column

# %%
Sales_Team_data.head()    #  Gives the top 5 rows
# Out:
#     Sales Team Lead PayGrade Region   EmpID  IsFound
# 0       Evans, Gina      C12     NW  EMP244     True
# 1     Lawson, Harry      C11     NW  EMP256     True
# 2    Bachmann, Jane      C13     NW  EMP234     True
# 3  Clement, Beverly      C14     SW  EMP267     True
# 4      Allen, Maude      C12     SW  EMP290     True

# %%
Sales_Team_data.shape     #  gives the dimensions of the dataframe

# %%
Sales_Team_data.nunique   # gives the number of unique values in each column

# %%
Sales_Team_data.dtypes   # returns data type

# %%
Sales_Team_data.head()   # returns first five lines of data captured

# %%
wk52_data.tail()         # returns last five lines of data captured
